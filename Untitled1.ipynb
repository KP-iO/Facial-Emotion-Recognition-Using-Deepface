# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace
import keras

# %%
img = cv2.imread('happyboy.jpeg')

# %%
# TO MAKE COLOUR RGB
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/1d/v3lv8nm90xq_6jn6zzd9bd0h0000gn/T/ipykernel_12648/1102709503.py in <module>
# ----> 1 predictions = DeepFace.analyze(img)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/deepface/DeepFace.py in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     307
#     308     if "race" in actions:
# --> 309         models["race"] = build_model("Race")
#     310     # ---------------------------------
#     311     resp_objects = []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/deepface/DeepFace.py in build_model(model_name)
#      78         model = models.get(model_name)
#      79         if model:
# ---> 80             model = model()
#      81             model_obj[model_name] = model
#      82         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/deepface/extendedmodels/Race.py in loadModel(url)
#      52         gdown.download(url, output, quiet=False)
#      53
# ---> 54     race_model.load_weights(home + "/.deepface/weights/race_model_single_batch.h5")
#      55
#      56     return race_model
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/opt/anaconda3/lib/python3.9/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, **kwds)
#     531                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     532                                  fs_page_size=fs_page_size)
# --> 533                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     534
#     535             if isinstance(libver, tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     224         if swmr and swmr_support:
#     225             flags |= h5f.ACC_SWMR_READ
# --> 226         fid = h5f.open(name, flags, fapl=fapl)
#     227     elif mode == 'r+':
#     228         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (truncated file: eof = 311438272, sblock->base_addr = 0, stored_eof = 537215296)

# %%
VGG_Weights_path = keras.utils.get_file(
pretrained_url.split("/")[-1], pretrained_url)
print(VGG_Weights_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1d/v3lv8nm90xq_6jn6zzd9bd0h0000gn/T/ipykernel_12648/2174604091.py in <module>
#       1 VGG_Weights_path = keras.utils.get_file(
# ----> 2 pretrained_url.split("/")[-1], pretrained_url)
#       3 print(VGG_Weights_path)
#
# NameError: name 'pretrained_url' is not defined
